# %% [markdown]
# ![SOALS.png](attachment:SOALS.png)

# %% [markdown]
# # 1 GANJIL

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGkkecilnol= sy.summation(sy.KroneckerDelta(k, 2) * z**(-k),(k, -sy.oo, 0))
#memanggil transformasi z kronecker delta sebagai X0
XGkkecilnol
# Out:
# 0

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGksamanol= sy.summation(sy.KroneckerDelta(k, 2) * z**(-k),(k, 0, 0))
#memanggil transformasi z kronecker delta sebagai X0
XGksamanol
# Out:
# 0

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGkbesarnol= sy.summation(sy.KroneckerDelta(k, 2) * z**(-k),(k, 1, sy.oo))
#memanggil transformasi z kronecker delta sebagai X0
XGkbesarnol
# Out:
# 1
# ──
#  2
# z

# %% [markdown]
# # 1 GENAP

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGkkecilnol= sy.summation(sy.KroneckerDelta(k, -3) * z**(-k),(k, -sy.oo, 0))
#memanggil transformasi z kronecker delta sebagai X0
XGkkecilnol
# Out:
#  3
# z

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGksamanol= sy.summation(sy.KroneckerDelta(k, -3) * z**(-k),(k, 0, 0))
#memanggil transformasi z kronecker delta sebagai X0
XGksamanol
# Out:
# 0

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

XGkbesarnol= sy.summation(sy.KroneckerDelta(k, -3) * z**(-k),(k, 1, sy.oo))
#memanggil transformasi z kronecker delta sebagai X0
XGkbesarnol
# Out:
# 0

# %% [markdown]
# # 2

# %%
import sympy as sy
sy.init_printing()

k = sy.symbols('k', integer=True)
z = sy.symbols('z', complex=True)

rez, imz = sy.symbols('rez imz', real=True)
X = (z+3) / (z-2)
X1= X.subs({z: rez+sy.I*imz})

sy.plotting.plot3d(abs(X1), (rez, -2, 2), (imz, -2, 2),
                  xlabel=r'$\Re\{z\}$', ylabel=r'$\Im\{z\}$',
                  title=r'$|X(z)|$')

# %%
zeros = sy.roots(sy.numer(X), z)
zeros
# Out:
# C:\Users\bayub\anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# C:\Users\bayub\anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# C:\Users\bayub\anaconda3\lib\site-packages\IPython\lib\latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# ...

# %%
poles = sy.roots(sy.denom(X), z)
poles
# Out:
# {2: 1}

# %%
import matplotlib.pyplot as plt
import sympy as sy
from matplotlib.patches import Circle

def zplane(p,z):
    fig = plt.figure(figsize=(10,10))
    ax  = fig.gca()
    
    for pole in p:
        plt.plot(complex(pole).real, complex(pole).imag, 'rx',
                markersize=10)
    for zero in z:
        plt.plot(complex(zero).real, complex(zero).imag, 'bo',
                markersize=10, fillstyle='none')
        
    unit_circle = Circle((0, 0), radius = 1, fill= False,
                        color='black', ls='solid', alpha=0.7)
    ax.add_patch(unit_circle)
    ax.axvline(0, color='0.7')
    ax.axhline(0, color='0.7')
    
    plt.axis('equal')
    plt.xlim((-3.2, 2.1))
    plt.ylim((-1, 1))
    plt.grid()
    plt.title('Z-plane')
    plt.xlabel(r'Re($z$)')
    plt.ylabel(r'Im($z$)')
    
poles = sy.roots(sy.denom(X), z)
zeros = sy.roots(sy.numer(X), z)

zplane(sy.roots(sy.denom(X), z), sy.roots(sy.numer(X), z))
