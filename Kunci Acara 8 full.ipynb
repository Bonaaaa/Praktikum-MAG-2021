# %% [markdown]
# ![msedge_MoEqc1yCv4.png](attachment:msedge_MoEqc1yCv4.png)

# %% [markdown]
# # GANJIL

# %%
import numpy as np
import matplotlib.pyplot as plt

def naive_DFT (x):
#fungsi DFT
    N = np.size(x)
    X = np.zeros(N,dtype=np.complex128)
    for m in range (0,N):
        for n in range (0,N):
            X[m] += x[n]*np.exp(-np.pi*2j*m*n/N)
    return X

def naive_IDFT (x):
#fungsi IDFT
    N = np.size(x)
    X = np.zeros(N, dtype=np.complex128)
    for m in range (0,N):
        for n in range (0, N):
            X[m] += x[n]*np.exp (-np.pi*2j*m*n/N)
    return X/N

N = 1000; #Jumlah sampel (sampling) data sinus
dt = 1/200 #interval sampling data sinus
t = np.linspace (0, N*dt, N)
#runtun waktu fungsi sinus berada pada rentang 0 sampai hasil kali sampling dengan intervalnya dan interval berupa interval samplingnya dipanggil sebagai t
ysin = np.sin(50*2*np.pi*t) + 0.5*np.sin(80*2*np.pi*t)
#fungsi sinus dipanggil sebagai ysin
ysinf = naive_DFT (ysin)
#DFT fungsi superposisi dipanggil sebagai ysinf
xsinf = np.linspace (0, 1/(2*dt), N//2)
#rentang sumbu x DFT fungsi superposisi dipanggil sebagai xsinf
ysinbalik = naive_IDFT (ysinf)
#IDFT fungsi superposisi dipanggil sebagai ysinbalik

plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.plot(t,ysin,'b')
plt.title('Data Mentah')
plt.ylabel('Amplitudo')
plt.xlabel('Waktu (s)')

plt.subplot(3,1,2)
plt.plot(xsinf, 2/N*np.abs(ysinf[0:N//2]),'r-')
plt.title('Power Spectral')
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Spectral')
plt.subplot(3,1,3)

plt.plot(t,ysinbalik,'b-')
plt.title('Data Hasil IDFT')
plt.ylabel('Amp')
plt.xlabel('Waktu (s)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bayub\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # GENAP

# %%
import numpy as np
import matplotlib.pyplot as plt

def naive_DFT (x):
#fungsi DFT
    N = np.size(x)
    X = np.zeros(N,dtype=np.complex128)
    for m in range (0,N):
        for n in range (0,N):
            X[m] += x[n]*np.exp(-np.pi*2j*m*n/N)
    return X

def naive_IDFT (x):
#fungsi IDFT
    N = np.size(x)
    X = np.zeros(N, dtype=np.complex128)
    for m in range (0,N):
        for n in range (0, N):
            X[m] += x[n]*np.exp (-np.pi*2j*m*n/N)
    return X/N

N = 1000; #Jumlah sampel (sampling) data random
dt = 1/200 #interval sampling data random
t = np.linspace (0, N*dt, N)
#runtun waktu fungsi random berada pada rentang 0 sampai hasil kali sampling dengan intervalnya dan interval berupa interval samplingnya dipanggil sebagai t
yra = np.random.rand(N,1)
yrand = yra - np.median(yra)
#fungsi random dipanggil sebagai yrand
yrand = naive_DFT (ysuper)
#DFT fungsi random dipanggil sebagai yrand
xrandf = np.linspace (0, 1/(2*dt), N//2)
#rentang sumbu x DFT fungsi random dipanggil sebagai xrandf
ysuperbalik = naive_IDFT (yrand)
#IDFT fungsi random dipanggil sebagai ysuperbalik

plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.plot(t,ysuper,'b')
plt.title('Data Mentah')
plt.ylabel('Amplitudo')
plt.xlabel('Waktu (s)')

plt.subplot(3,1,2)
plt.plot(xrandf, 2/N*np.abs(yrand[0:N//2]),'r-')
plt.title('Power Spectral')
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Spectral')
plt.subplot(3,1,3)

plt.plot(t,ysuperbalik,'b-')
plt.title('Data Hasil IDFT')
plt.ylabel('Amp')
plt.xlabel('Waktu (s)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bayub\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# ![msedge_twBzkp2ZSY.png](attachment:msedge_twBzkp2ZSY.png)

# %% [markdown]
# # GANJIL

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft,ifft

N = 1000; #Jumlah sampel (sampling) data sinus dan random
dt = 1/200 #interval sampling data sinus dan random
t = np.linspace (0, N*dt, N)
#runtun waktu fungsi sinus dan random berada pada rentang 0 sampai hasil kali sampling dengan intervalnya dan interval berupa interval samplingnya dipanggil sebagai t
ysin = np.sin(4*np.pi*t)
#fungsi sinus dipanggil sebagai ysin
ysinf = fft (ysin)
#FFT fungsi superposisi dipanggil sebagai ysinf
xsuperf = np.linspace (0, 1/(2*dt), N//2)
#rentang sumbu x FFT fungsi superposisi dipanggil sebagai xsuperf
ysinbalik = ifft (ysinf)
#IFFT fungsi superposisi dipanggil sebagai ysinbalik

plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.plot(t,ysin,'b')
plt.title('Data Mentah')
plt.ylabel('Amplitudo')
plt.xlabel('Waktu (s)')

plt.subplot(3,1,2)
plt.plot(xsuperf, 2/N*np.abs(ysinf[0:N//2]),'r-')
plt.title('Power Spectral atau Frekuensi Respon')
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Spectral')
plt.subplot(3,1,3)

plt.plot(t,ysinbalik,'b-')
plt.title('Data Hasil IFFT')
plt.ylabel('Amp')
plt.xlabel('Waktu (s)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bayub\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # GENAP

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft,ifft

N = 1000; #Jumlah sampel (sampling) data sinus dan random
dt = 1/200 #interval sampling data sinus dan random
t = np.linspace (0, N*dt, N)
#runtun waktu fungsi sinus dan random berada pada rentang 0 sampai hasil kali sampling dengan intervalnya dan interval berupa interval samplingnya dipanggil sebagai t
yra = np.random.rand(N,1)
yrand = yra - np.median(yra)
#fungsi random dipanggil sebagai yrand
yrandfft = fft (yrand)
#FFT fungsi superposisi dipanggil sebagai yrandfft
xrandf = np.linspace (0, 1/(2*dt), N//2)
#rentang sumbu x FFT fungsi superposisi dipanggil sebagai xrandf
yrandbalik = ifft (yrandfft)
#IFFT fungsi superposisi dipanggil sebagai yrandbalik

plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.plot(t,yrand,'b')
plt.title('Data Mentah')
plt.ylabel('Amplitudo')
plt.xlabel('Waktu (s)')

plt.subplot(3,1,2)
plt.plot(xrandf, 2/N*np.abs(yrandfft[0:N//2]),'r-')
plt.title('Power Spectral atau Frekuensi Respon')
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Spectral')
plt.subplot(3,1,3)

plt.plot(t,yrandbalik,'b-')
plt.title('Data Hasil IFFT')
plt.ylabel('Amp')
plt.xlabel('Waktu (s)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bayub\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
